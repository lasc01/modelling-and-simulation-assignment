# %%
import simpy

# %%
# Parameters for scaled simulation
NUM_CONTAINERS = 106
NUM_TRUCKS = 9  
NUM_CRANES = 3   

TRUCK_ROUND_TRIP_TIME = 2.0   # hours per container (loading + travel + unloading + return)
CRANE_HANDLING_TIME = 0.5     # hours per container

# %%
class Stats:
    def __init__(self):
        self.truck_wait_times = []
        self.crane_wait_times = []
        self.truck_busy_time = 0.0
        self.crane_busy_time = 0.0

# %%
def container(env, name, trucks, cranes, stats):
    arrival_time = env.now
    # Request truck and measure wait time
    with trucks.request() as req_truck:
        truck_req_time = env.now
        yield req_truck
        truck_wait = env.now - truck_req_time
        stats.truck_wait_times.append(truck_wait)
        
        print(f"{env.now:.2f}h - {name} loading onto truck after waiting {truck_wait:.2f}h")
        start = env.now
        yield env.timeout(TRUCK_ROUND_TRIP_TIME)
        stats.truck_busy_time += TRUCK_ROUND_TRIP_TIME
        print(f"{env.now:.2f}h - {name} arrived at terminal")


    # Request crane and measure wait time
    with cranes.request() as req_crane:
        crane_req_time = env.now
        yield req_crane
        crane_wait = env.now - crane_req_time
        stats.crane_wait_times.append(crane_wait)
        
        print(f"{env.now:.2f}h - {name} loading onto train after waiting {crane_wait:.2f}h")
        yield env.timeout(CRANE_HANDLING_TIME)
        stats.crane_busy_time += CRANE_HANDLING_TIME
        print(f"{env.now:.2f}h - {name} loaded onto train")

# %%
def run_scaled_simulation():
    env = simpy.Environment()
    trucks = simpy.Resource(env, capacity=NUM_TRUCKS)
    cranes = simpy.Resource(env, capacity=NUM_CRANES)
    stats = Stats()

    for i in range(NUM_CONTAINERS):
        env.process(container(env, f"C{i+1}", trucks, cranes, stats))

    env.run(until=24)

    # Calculate and print summary statistics
    avg_truck_wait = sum(stats.truck_wait_times) / len(stats.truck_wait_times)
    avg_crane_wait = sum(stats.crane_wait_times) / len(stats.crane_wait_times)

    truck_util = stats.truck_busy_time / (NUM_TRUCKS * 24) * 100
    crane_util = stats.crane_busy_time / (NUM_CRANES * 24) * 100

    print("\n--- Simulation Summary ---")
    print(f"Average Truck Wait Time: {avg_truck_wait:.2f} hours")
    print(f"Average Crane Wait Time: {avg_crane_wait:.2f} hours")
    print(f"Truck Utilization: {truck_util:.2f}%")
    print(f"Crane Utilization: {crane_util:.2f}%")

if __name__ == "__main__":
    run_scaled_simulation()
# Out:
# 0.00h - C1 loading onto truck after waiting 0.00h
# 0.00h - C2 loading onto truck after waiting 0.00h
# 0.00h - C3 loading onto truck after waiting 0.00h
# 0.00h - C4 loading onto truck after waiting 0.00h
# 0.00h - C5 loading onto truck after waiting 0.00h
# 0.00h - C6 loading onto truck after waiting 0.00h
# 0.00h - C7 loading onto truck after waiting 0.00h
# 0.00h - C8 loading onto truck after waiting 0.00h
# 0.00h - C9 loading onto truck after waiting 0.00h
# 2.00h - C1 arrived at terminal
# 2.00h - C2 arrived at terminal
# 2.00h - C3 arrived at terminal
# 2.00h - C4 arrived at terminal
# 2.00h - C5 arrived at terminal
# 2.00h - C6 arrived at terminal
# 2.00h - C7 arrived at terminal
# 2.00h - C8 arrived at terminal
# 2.00h - C9 arrived at terminal
# 2.00h - C1 loading onto train after waiting 0.00h
# 2.00h - C2 loading onto train after waiting 0.00h
# 2.00h - C3 loading onto train after waiting 0.00h
# 2.00h - C10 loading onto truck after waiting 2.00h
# 2.00h - C11 loading onto truck after waiting 2.00h
# 2.00h - C12 loading onto truck after waiting 2.00h
# 2.00h - C13 loading onto truck after waiting 2.00h
# 2.00h - C14 loading onto truck after waiting 2.00h
# 2.00h - C15 loading onto truck after waiting 2.00h
# 2.00h - C16 loading onto truck after waiting 2.00h
# 2.00h - C17 loading onto truck after waiting 2.00h
# 2.00h - C18 loading onto truck after waiting 2.00h
# 2.50h - C1 loaded onto train
# 2.50h - C2 loaded onto train
# 2.50h - C3 loaded onto train
# 2.50h - C4 loading onto train after waiting 0.50h
# 2.50h - C5 loading onto train after waiting 0.50h
# 2.50h - C6 loading onto train after waiting 0.50h
# 3.00h - C4 loaded onto train
# 3.00h - C5 loaded onto train
# 3.00h - C6 loaded onto train
# 3.00h - C7 loading onto train after waiting 1.00h
# 3.00h - C8 loading onto train after waiting 1.00h
# 3.00h - C9 loading onto train after waiting 1.00h
# 3.50h - C7 loaded onto train
# 3.50h - C8 loaded onto train
# 3.50h - C9 loaded onto train
# 4.00h - C10 arrived at terminal
# 4.00h - C11 arrived at terminal
# 4.00h - C12 arrived at terminal
# 4.00h - C13 arrived at terminal
# 4.00h - C14 arrived at terminal
# 4.00h - C15 arrived at terminal
# 4.00h - C16 arrived at terminal
# 4.00h - C17 arrived at terminal
# 4.00h - C18 arrived at terminal
# 4.00h - C10 loading onto train after waiting 0.00h
# 4.00h - C11 loading onto train after waiting 0.00h
# 4.00h - C12 loading onto train after waiting 0.00h
# 4.00h - C19 loading onto truck after waiting 4.00h
# 4.00h - C20 loading onto truck after waiting 4.00h
# 4.00h - C21 loading onto truck after waiting 4.00h
# 4.00h - C22 loading onto truck after waiting 4.00h
# 4.00h - C23 loading onto truck after waiting 4.00h
# 4.00h - C24 loading onto truck after waiting 4.00h
# 4.00h - C25 loading onto truck after waiting 4.00h
# 4.00h - C26 loading onto truck after waiting 4.00h
# 4.00h - C27 loading onto truck after waiting 4.00h
# 4.50h - C10 loaded onto train
# 4.50h - C11 loaded onto train
# 4.50h - C12 loaded onto train
# 4.50h - C13 loading onto train after waiting 0.50h
# 4.50h - C14 loading onto train after waiting 0.50h
# 4.50h - C15 loading onto train after waiting 0.50h
# 5.00h - C13 loaded onto train
# 5.00h - C14 loaded onto train
# 5.00h - C15 loaded onto train
# 5.00h - C16 loading onto train after waiting 1.00h
# 5.00h - C17 loading onto train after waiting 1.00h
# 5.00h - C18 loading onto train after waiting 1.00h
# 5.50h - C16 loaded onto train
# 5.50h - C17 loaded onto train
# 5.50h - C18 loaded onto train
# 6.00h - C19 arrived at terminal
# 6.00h - C20 arrived at terminal
# 6.00h - C21 arrived at terminal
# 6.00h - C22 arrived at terminal
# 6.00h - C23 arrived at terminal
# 6.00h - C24 arrived at terminal
# 6.00h - C25 arrived at terminal
# 6.00h - C26 arrived at terminal
# 6.00h - C27 arrived at terminal
# 6.00h - C19 loading onto train after waiting 0.00h
# 6.00h - C20 loading onto train after waiting 0.00h
# 6.00h - C21 loading onto train after waiting 0.00h
# 6.00h - C28 loading onto truck after waiting 6.00h
# 6.00h - C29 loading onto truck after waiting 6.00h
# 6.00h - C30 loading onto truck after waiting 6.00h
# 6.00h - C31 loading onto truck after waiting 6.00h
# 6.00h - C32 loading onto truck after waiting 6.00h
# 6.00h - C33 loading onto truck after waiting 6.00h
# 6.00h - C34 loading onto truck after waiting 6.00h
# 6.00h - C35 loading onto truck after waiting 6.00h
# 6.00h - C36 loading onto truck after waiting 6.00h
# 6.50h - C19 loaded onto train
# 6.50h - C20 loaded onto train
# 6.50h - C21 loaded onto train
# 6.50h - C22 loading onto train after waiting 0.50h
# 6.50h - C23 loading onto train after waiting 0.50h
# 6.50h - C24 loading onto train after waiting 0.50h
# 7.00h - C22 loaded onto train
# 7.00h - C23 loaded onto train
# 7.00h - C24 loaded onto train
# 7.00h - C25 loading onto train after waiting 1.00h
# 7.00h - C26 loading onto train after waiting 1.00h
# 7.00h - C27 loading onto train after waiting 1.00h
# 7.50h - C25 loaded onto train
# 7.50h - C26 loaded onto train
# 7.50h - C27 loaded onto train
# 8.00h - C28 arrived at terminal
# 8.00h - C29 arrived at terminal
# 8.00h - C30 arrived at terminal
# 8.00h - C31 arrived at terminal
# 8.00h - C32 arrived at terminal
# 8.00h - C33 arrived at terminal
# 8.00h - C34 arrived at terminal
# 8.00h - C35 arrived at terminal
# 8.00h - C36 arrived at terminal
# 8.00h - C28 loading onto train after waiting 0.00h
# 8.00h - C29 loading onto train after waiting 0.00h
# 8.00h - C30 loading onto train after waiting 0.00h
# 8.00h - C37 loading onto truck after waiting 8.00h
# 8.00h - C38 loading onto truck after waiting 8.00h
# 8.00h - C39 loading onto truck after waiting 8.00h
# 8.00h - C40 loading onto truck after waiting 8.00h
# 8.00h - C41 loading onto truck after waiting 8.00h
# 8.00h - C42 loading onto truck after waiting 8.00h
# 8.00h - C43 loading onto truck after waiting 8.00h
# 8.00h - C44 loading onto truck after waiting 8.00h
# 8.00h - C45 loading onto truck after waiting 8.00h
# 8.50h - C28 loaded onto train
# 8.50h - C29 loaded onto train
# 8.50h - C30 loaded onto train
# 8.50h - C31 loading onto train after waiting 0.50h
# 8.50h - C32 loading onto train after waiting 0.50h
# 8.50h - C33 loading onto train after waiting 0.50h
# 9.00h - C31 loaded onto train
# 9.00h - C32 loaded onto train
# 9.00h - C33 loaded onto train
# 9.00h - C34 loading onto train after waiting 1.00h
# 9.00h - C35 loading onto train after waiting 1.00h
# 9.00h - C36 loading onto train after waiting 1.00h
# 9.50h - C34 loaded onto train
# 9.50h - C35 loaded onto train
# 9.50h - C36 loaded onto train
# 10.00h - C37 arrived at terminal
# 10.00h - C38 arrived at terminal
# 10.00h - C39 arrived at terminal
# 10.00h - C40 arrived at terminal
# 10.00h - C41 arrived at terminal
# 10.00h - C42 arrived at terminal
# 10.00h - C43 arrived at terminal
# 10.00h - C44 arrived at terminal
# 10.00h - C45 arrived at terminal
# 10.00h - C37 loading onto train after waiting 0.00h
# 10.00h - C38 loading onto train after waiting 0.00h
# 10.00h - C39 loading onto train after waiting 0.00h
# 10.00h - C46 loading onto truck after waiting 10.00h
# 10.00h - C47 loading onto truck after waiting 10.00h
# 10.00h - C48 loading onto truck after waiting 10.00h
# 10.00h - C49 loading onto truck after waiting 10.00h
# 10.00h - C50 loading onto truck after waiting 10.00h
# 10.00h - C51 loading onto truck after waiting 10.00h
# 10.00h - C52 loading onto truck after waiting 10.00h
# 10.00h - C53 loading onto truck after waiting 10.00h
# 10.00h - C54 loading onto truck after waiting 10.00h
# 10.50h - C37 loaded onto train
# 10.50h - C38 loaded onto train
# 10.50h - C39 loaded onto train
# 10.50h - C40 loading onto train after waiting 0.50h
# 10.50h - C41 loading onto train after waiting 0.50h
# 10.50h - C42 loading onto train after waiting 0.50h
# 11.00h - C40 loaded onto train
# 11.00h - C41 loaded onto train
# 11.00h - C42 loaded onto train
# 11.00h - C43 loading onto train after waiting 1.00h
# 11.00h - C44 loading onto train after waiting 1.00h
# 11.00h - C45 loading onto train after waiting 1.00h
# 11.50h - C43 loaded onto train
# 11.50h - C44 loaded onto train
# 11.50h - C45 loaded onto train
# 12.00h - C46 arrived at terminal
# 12.00h - C47 arrived at terminal
# 12.00h - C48 arrived at terminal
# 12.00h - C49 arrived at terminal
# 12.00h - C50 arrived at terminal
# 12.00h - C51 arrived at terminal
# 12.00h - C52 arrived at terminal
# 12.00h - C53 arrived at terminal
# 12.00h - C54 arrived at terminal
# 12.00h - C46 loading onto train after waiting 0.00h
# 12.00h - C47 loading onto train after waiting 0.00h
# 12.00h - C48 loading onto train after waiting 0.00h
# 12.00h - C55 loading onto truck after waiting 12.00h
# 12.00h - C56 loading onto truck after waiting 12.00h
# 12.00h - C57 loading onto truck after waiting 12.00h
# 12.00h - C58 loading onto truck after waiting 12.00h
# 12.00h - C59 loading onto truck after waiting 12.00h
# 12.00h - C60 loading onto truck after waiting 12.00h
# 12.00h - C61 loading onto truck after waiting 12.00h
# 12.00h - C62 loading onto truck after waiting 12.00h
# 12.00h - C63 loading onto truck after waiting 12.00h
# 12.50h - C46 loaded onto train
# 12.50h - C47 loaded onto train
# 12.50h - C48 loaded onto train
# 12.50h - C49 loading onto train after waiting 0.50h
# 12.50h - C50 loading onto train after waiting 0.50h
# 12.50h - C51 loading onto train after waiting 0.50h
# 13.00h - C49 loaded onto train
# 13.00h - C50 loaded onto train
# 13.00h - C51 loaded onto train
# 13.00h - C52 loading onto train after waiting 1.00h
# 13.00h - C53 loading onto train after waiting 1.00h
# 13.00h - C54 loading onto train after waiting 1.00h
# 13.50h - C52 loaded onto train
# 13.50h - C53 loaded onto train
# 13.50h - C54 loaded onto train
# 14.00h - C55 arrived at terminal
# 14.00h - C56 arrived at terminal
# 14.00h - C57 arrived at terminal
# 14.00h - C58 arrived at terminal
# 14.00h - C59 arrived at terminal
# 14.00h - C60 arrived at terminal
# 14.00h - C61 arrived at terminal
# 14.00h - C62 arrived at terminal
# 14.00h - C63 arrived at terminal
# 14.00h - C55 loading onto train after waiting 0.00h
# 14.00h - C56 loading onto train after waiting 0.00h
# 14.00h - C57 loading onto train after waiting 0.00h
# 14.00h - C64 loading onto truck after waiting 14.00h
# 14.00h - C65 loading onto truck after waiting 14.00h
# 14.00h - C66 loading onto truck after waiting 14.00h
# 14.00h - C67 loading onto truck after waiting 14.00h
# 14.00h - C68 loading onto truck after waiting 14.00h
# 14.00h - C69 loading onto truck after waiting 14.00h
# 14.00h - C70 loading onto truck after waiting 14.00h
# 14.00h - C71 loading onto truck after waiting 14.00h
# 14.00h - C72 loading onto truck after waiting 14.00h
# 14.50h - C55 loaded onto train
# 14.50h - C56 loaded onto train
# 14.50h - C57 loaded onto train
# 14.50h - C58 loading onto train after waiting 0.50h
# 14.50h - C59 loading onto train after waiting 0.50h
# 14.50h - C60 loading onto train after waiting 0.50h
# 15.00h - C58 loaded onto train
# 15.00h - C59 loaded onto train
# 15.00h - C60 loaded onto train
# 15.00h - C61 loading onto train after waiting 1.00h
# 15.00h - C62 loading onto train after waiting 1.00h
# 15.00h - C63 loading onto train after waiting 1.00h
# 15.50h - C61 loaded onto train
# 15.50h - C62 loaded onto train
# 15.50h - C63 loaded onto train
# 16.00h - C64 arrived at terminal
# 16.00h - C65 arrived at terminal
# 16.00h - C66 arrived at terminal
# 16.00h - C67 arrived at terminal
# 16.00h - C68 arrived at terminal
# 16.00h - C69 arrived at terminal
# 16.00h - C70 arrived at terminal
# 16.00h - C71 arrived at terminal
# 16.00h - C72 arrived at terminal
# 16.00h - C64 loading onto train after waiting 0.00h
# 16.00h - C65 loading onto train after waiting 0.00h
# 16.00h - C66 loading onto train after waiting 0.00h
# 16.00h - C73 loading onto truck after waiting 16.00h
# 16.00h - C74 loading onto truck after waiting 16.00h
# 16.00h - C75 loading onto truck after waiting 16.00h
# 16.00h - C76 loading onto truck after waiting 16.00h
# 16.00h - C77 loading onto truck after waiting 16.00h
# 16.00h - C78 loading onto truck after waiting 16.00h
# 16.00h - C79 loading onto truck after waiting 16.00h
# 16.00h - C80 loading onto truck after waiting 16.00h
# 16.00h - C81 loading onto truck after waiting 16.00h
# 16.50h - C64 loaded onto train
# 16.50h - C65 loaded onto train
# 16.50h - C66 loaded onto train
# 16.50h - C67 loading onto train after waiting 0.50h
# 16.50h - C68 loading onto train after waiting 0.50h
# 16.50h - C69 loading onto train after waiting 0.50h
# 17.00h - C67 loaded onto train
# 17.00h - C68 loaded onto train
# 17.00h - C69 loaded onto train
# 17.00h - C70 loading onto train after waiting 1.00h
# 17.00h - C71 loading onto train after waiting 1.00h
# 17.00h - C72 loading onto train after waiting 1.00h
# 17.50h - C70 loaded onto train
# 17.50h - C71 loaded onto train
# 17.50h - C72 loaded onto train
# 18.00h - C73 arrived at terminal
# 18.00h - C74 arrived at terminal
# 18.00h - C75 arrived at terminal
# 18.00h - C76 arrived at terminal
# 18.00h - C77 arrived at terminal
# 18.00h - C78 arrived at terminal
# 18.00h - C79 arrived at terminal
# 18.00h - C80 arrived at terminal
# 18.00h - C81 arrived at terminal
# 18.00h - C73 loading onto train after waiting 0.00h
# 18.00h - C74 loading onto train after waiting 0.00h
# 18.00h - C75 loading onto train after waiting 0.00h
# 18.00h - C82 loading onto truck after waiting 18.00h
# 18.00h - C83 loading onto truck after waiting 18.00h
# 18.00h - C84 loading onto truck after waiting 18.00h
# 18.00h - C85 loading onto truck after waiting 18.00h
# 18.00h - C86 loading onto truck after waiting 18.00h
# 18.00h - C87 loading onto truck after waiting 18.00h
# 18.00h - C88 loading onto truck after waiting 18.00h
# 18.00h - C89 loading onto truck after waiting 18.00h
# 18.00h - C90 loading onto truck after waiting 18.00h
# 18.50h - C73 loaded onto train
# 18.50h - C74 loaded onto train
# 18.50h - C75 loaded onto train
# 18.50h - C76 loading onto train after waiting 0.50h
# 18.50h - C77 loading onto train after waiting 0.50h
# 18.50h - C78 loading onto train after waiting 0.50h
# 19.00h - C76 loaded onto train
# 19.00h - C77 loaded onto train
# 19.00h - C78 loaded onto train
# 19.00h - C79 loading onto train after waiting 1.00h
# 19.00h - C80 loading onto train after waiting 1.00h
# 19.00h - C81 loading onto train after waiting 1.00h
# 19.50h - C79 loaded onto train
# 19.50h - C80 loaded onto train
# 19.50h - C81 loaded onto train
# 20.00h - C82 arrived at terminal
# 20.00h - C83 arrived at terminal
# 20.00h - C84 arrived at terminal
# 20.00h - C85 arrived at terminal
# 20.00h - C86 arrived at terminal
# 20.00h - C87 arrived at terminal
# 20.00h - C88 arrived at terminal
# 20.00h - C89 arrived at terminal
# 20.00h - C90 arrived at terminal
# 20.00h - C82 loading onto train after waiting 0.00h
# 20.00h - C83 loading onto train after waiting 0.00h
# 20.00h - C84 loading onto train after waiting 0.00h
# 20.00h - C91 loading onto truck after waiting 20.00h
# 20.00h - C92 loading onto truck after waiting 20.00h
# 20.00h - C93 loading onto truck after waiting 20.00h
# 20.00h - C94 loading onto truck after waiting 20.00h
# 20.00h - C95 loading onto truck after waiting 20.00h
# 20.00h - C96 loading onto truck after waiting 20.00h
# 20.00h - C97 loading onto truck after waiting 20.00h
# 20.00h - C98 loading onto truck after waiting 20.00h
# 20.00h - C99 loading onto truck after waiting 20.00h
# 20.50h - C82 loaded onto train
# 20.50h - C83 loaded onto train
# 20.50h - C84 loaded onto train
# 20.50h - C85 loading onto train after waiting 0.50h
# 20.50h - C86 loading onto train after waiting 0.50h
# 20.50h - C87 loading onto train after waiting 0.50h
# 21.00h - C85 loaded onto train
# 21.00h - C86 loaded onto train
# 21.00h - C87 loaded onto train
# 21.00h - C88 loading onto train after waiting 1.00h
# 21.00h - C89 loading onto train after waiting 1.00h
# 21.00h - C90 loading onto train after waiting 1.00h
# 21.50h - C88 loaded onto train
# 21.50h - C89 loaded onto train
# 21.50h - C90 loaded onto train
# 22.00h - C91 arrived at terminal
# 22.00h - C92 arrived at terminal
# 22.00h - C93 arrived at terminal
# 22.00h - C94 arrived at terminal
# 22.00h - C95 arrived at terminal
# 22.00h - C96 arrived at terminal
# 22.00h - C97 arrived at terminal
# 22.00h - C98 arrived at terminal
# 22.00h - C99 arrived at terminal
# 22.00h - C91 loading onto train after waiting 0.00h
# 22.00h - C92 loading onto train after waiting 0.00h
# 22.00h - C93 loading onto train after waiting 0.00h
# 22.00h - C100 loading onto truck after waiting 22.00h
# 22.00h - C101 loading onto truck after waiting 22.00h
# 22.00h - C102 loading onto truck after waiting 22.00h
# 22.00h - C103 loading onto truck after waiting 22.00h
# 22.00h - C104 loading onto truck after waiting 22.00h
# 22.00h - C105 loading onto truck after waiting 22.00h
# 22.00h - C106 loading onto truck after waiting 22.00h
# 22.50h - C91 loaded onto train
# 22.50h - C92 loaded onto train
# 22.50h - C93 loaded onto train
# 22.50h - C94 loading onto train after waiting 0.50h
# 22.50h - C95 loading onto train after waiting 0.50h
# 22.50h - C96 loading onto train after waiting 0.50h
# 23.00h - C94 loaded onto train
# 23.00h - C95 loaded onto train
# 23.00h - C96 loaded onto train
# 23.00h - C97 loading onto train after waiting 1.00h
# 23.00h - C98 loading onto train after waiting 1.00h
# 23.00h - C99 loading onto train after waiting 1.00h
# 23.50h - C97 loaded onto train
# 23.50h - C98 loaded onto train
# 23.50h - C99 loaded onto train
#
# --- Simulation Summary ---
# Average Truck Wait Time: 10.79 hours
# Average Crane Wait Time: 0.50 hours
# Truck Utilization: 91.67%
# Crane Utilization: 68.75%
